# %%
Lab 1 - Box Plot

# %%
import pandas as pd
import matplotlib.pyplot as plt
d= pd.read_csv('./content/tips_bp.csv')
plt.boxplot(d, vert=None)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
d= pd.read_csv('./content/tips_bp.csv')
d.boxplot(column=["total_bill"])
plt.show()
